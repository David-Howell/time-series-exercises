# %%
for i in range(7):
#     print(f'''

# <a id="Store{i}"> </a>
# <div class= "alert alert-block alert-info">
# </div>

# ***
# ''')
    print(f'[__Store: {i} |__](#Store{i})')
    
for i in range(7):
#     print(f'''
# <a id="OPS_{i}"> </a>
# <div class= "alert alert-block alert-info">
# </div>

# ***
# ''')
    print(f'[__OPSD: {i} |__](#OPS_{i})')
    
# for i in range(5):
#     print(f'''
# <a id="flights_{i}"> </a>
# <div class= "alert alert-block alert-info">
# </div>

# ***
# ''')
    # print(f'[__Flights: {i} |__](#flights_{i})')
    
# for i in range(6):
#     print(f'''
# <a id="B2_{i}"> </a>
# <div class= "alert alert-block alert-info">
# </div>

# ***
# ''')
    # print(f'[__Bonus_2: {i} |__](#B2_{i})')
# Out:
# [__Store: 0 |__](#Store0)
# [__Store: 1 |__](#Store1)
# [__Store: 2 |__](#Store2)
# [__Store: 3 |__](#Store3)
# [__Store: 4 |__](#Store4)
# [__Store: 5 |__](#Store5)
# [__Store: 6 |__](#Store6)
# [__OPSD: 0 |__](#OPS_0)
# [__OPSD: 1 |__](#OPS_1)
# [__OPSD: 2 |__](#OPS_2)
# [__OPSD: 3 |__](#OPS_3)
# [__OPSD: 4 |__](#OPS_4)
# [__OPSD: 5 |__](#OPS_5)
# [__OPSD: 6 |__](#OPS_6)

# %% [markdown]
# # Exercises
# The end result of this exercise should be a file named `prepare.py`.
#
# **[__Store:__](#Store0)**
#
# [__Store: 1 |__](#Store1)
# [__Store: 2 |__](#Store2)
# [__Store: 3 |__](#Store3)
# [__Store: 4 |__](#Store4)
# [__Store: 5 |__](#Store5)
# [__Store: 6 |__](#Store6)
#
# **[__OPSD:__](#OPS_0)**
#
# [__OPSD: 1 |__](#OPS_1)
# [__OPSD: 2 |__](#OPS_2)
# [__OPSD: 3 |__](#OPS_3)
# [__OPSD: 4 |__](#OPS_4)
# [__OPSD: 5 |__](#OPS_5)
# [__OPSD: 6 |__](#OPS_6)

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from acquire import all_sales, open_power_systems_data
from wrangle import summarize
from viz import boxplots, hists, heatmaps

# %%
from formating import bold, dtf, flat, percent, strike, underline

# %% [markdown]
# <a id="Store0"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ## Using your store items data:

# %%
df = all_sales()

# %%
summarize(df, too_long=15, q=5)
# Out:
#     DataFrame .head():
#     -----------------
# |    |   item |   sale_amount | sale_date                     |   sale_id |   store | store_address          | store_city   | store_state   |   store_zipcode | item_brand   | item_name                      |   item_price |   item_upc12 |   item_upc14 |
# |---:|-------:|--------------:|:------------------------------|----------:|--------:|:-----------------------|:-------------|:--------------|----------------:|:-------------|:-------------------------------|-------------:|-------------:|-------------:|
# |  0 |      1 |            13 | Tue, 01 Jan 2013 00:00:00 GMT |         1 |       1 | 12125 Alamo Ranch Pkwy | San Antonio  | TX            |           78253 | Riceland     | Riceland American Jazmine Rice |         0.84 |  35200264013 |  35200264013 |
# ...

# %% [markdown]
# <a id="Store1"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 1. Convert date column to datetime format.

# %%
df.sale_date
# Out:
# 0         Tue, 01 Jan 2013 00:00:00 GMT
# 1         Wed, 02 Jan 2013 00:00:00 GMT
# 2         Thu, 03 Jan 2013 00:00:00 GMT
# 3         Fri, 04 Jan 2013 00:00:00 GMT
# 4         Sat, 05 Jan 2013 00:00:00 GMT
#                       ...
# 912995    Wed, 27 Dec 2017 00:00:00 GMT
# 912996    Thu, 28 Dec 2017 00:00:00 GMT
# 912997    Fri, 29 Dec 2017 00:00:00 GMT
# 912998    Sat, 30 Dec 2017 00:00:00 GMT
# 912999    Sun, 31 Dec 2017 00:00:00 GMT
# Name: sale_date, Length: 913000, dtype: object

# %%
df.sale_date[0]
# Out:
# 'Tue, 01 Jan 2013 00:00:00 GMT'

# %%
df.sale_date = df.sale_date.str.replace('00:00:00 GMT', '')
df.sale_date
# Out:
# 0         Tue, 01 Jan 2013
# 1         Wed, 02 Jan 2013
# 2         Thu, 03 Jan 2013
# 3         Fri, 04 Jan 2013
# 4         Sat, 05 Jan 2013
#                 ...
# 912995    Wed, 27 Dec 2017
# 912996    Thu, 28 Dec 2017
# 912997    Fri, 29 Dec 2017
# 912998    Sat, 30 Dec 2017
# 912999    Sun, 31 Dec 2017
# Name: sale_date, Length: 913000, dtype: object

# %%
df.sale_date[0]
# Out:
# 'Tue, 01 Jan 2013 '

# %%
# df.sale_date = 
split_date = df.sale_date.str.split(' ', n=1, expand=True)
# df.sale_date
split_date[0]
# Out:
# 0         Tue,
# 1         Wed,
# 2         Thu,
# 3         Fri,
# 4         Sat,
#           ...
# 912995    Wed,
# 912996    Thu,
# 912997    Fri,
# 912998    Sat,
# 912999    Sun,
# Name: 0, Length: 913000, dtype: object

# %%
split_date[1] = split_date[1].str.strip()

# %%
split_date[0] = split_date[0].str.replace(',','')

# %%
df.sale_date = split_date[1]
df['weekday'] = split_date[0]
df
# Out:
#         item  sale_amount    sale_date  ...   item_upc12   item_upc14 weekday
# 0          1         13.0  01 Jan 2013  ...  35200264013  35200264013     Tue
# 1          1         11.0  02 Jan 2013  ...  35200264013  35200264013     Wed
# 2          1         14.0  03 Jan 2013  ...  35200264013  35200264013     Thu
# 3          1         13.0  04 Jan 2013  ...  35200264013  35200264013     Fri
# 4          1         10.0  05 Jan 2013  ...  35200264013  35200264013     Sat
# ...      ...          ...          ...  ...          ...          ...     ...
# 912995    50         63.0  27 Dec 2017  ...  47445919221  47445919221     Wed
# 912996    50         59.0  28 Dec 2017  ...  47445919221  47445919221     Thu
# 912997    50         74.0  29 Dec 2017  ...  47445919221  47445919221     Fri
# 912998    50         62.0  30 Dec 2017  ...  47445919221  47445919221     Sat
# 912999    50         82.0  31 Dec 2017  ...  47445919221  47445919221     Sun
#
# [913000 rows x 15 columns]

# %%
df.sale_date[0]
# Out:
# '01 Jan 2013'

# %%
df.sale_date = pd.to_datetime(df.sale_date, format='%d %b %Y')

# %%
df.sale_date
# Out:
# 0        2013-01-01
# 1        2013-01-02
# 2        2013-01-03
# 3        2013-01-04
# 4        2013-01-05
#             ...
# 912995   2017-12-27
# 912996   2017-12-28
# 912997   2017-12-29
# 912998   2017-12-30
# 912999   2017-12-31
# Name: sale_date, Length: 913000, dtype: datetime64[ns]

# %%
dtf()
# Out:
# |Directive|Meaning|Example|Notes|
# |:-------:|:------|:------|:----|
# |%a|Weekday as locale’s abbreviated name.|Sun, Mon, …, Sat (en_US);So, Mo, …, Sa (de_DE)|(1)|
# |%A|Weekday as locale’s full name.|Sunday, Monday, …, Saturday (en_US);Sonntag, Montag, …, Samstag (de_DE)|(1)|
# |%w|Weekday as a decimal number, where 0 is Sunday and 6 is Saturday.|0, 1, …, 6|
# |%d|Day of the month as a zero-padded decimal number.|01, 02, …, 31|(9)|
# |%b|Month as locale’s abbreviated name.|Jan, Feb, …, Dec (en_US) ;Jan, Feb, …, Dez (de_DE)|(1)|
# |%B|Month as locale’s full name.|January, February, …, December (en_US); Januar, Februar, …, Dezember (de_DE)|(1)|
# |%m|Month as a zero-padded decimal number.|01, 02, …, 12|(9)|
# |%y|Year without century as a zero-padded decimal number.|00, 01, …, 99|(9)|
# |%Y|Year with century as a decimal number.|0001, 0002, …, 2013, 2014, …, 9998, 9999|(2)|
# |%H|Hour (24-hour clock) as a zero-padded decimal number.|00, 01, …, 23|(9)|
# ...

# %% [markdown]
# <a id="Store2"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 2. Plot the distribution of sale_amount and item_price.

# %%
# plt.figure(figsize=(12,8))

# fig = sns.displot(data=df
#             , x= 'sale_amount'
#             , y= 'item_price'
#             # , hue= 'weekday'
#             , height= 10
#                  )
# # fig.show()

# %%
plt.figure(figsize=(12,8))

fig = sns.displot(data=df
            , y= 'sale_amount'
            , x= 'item_price'
            # , hue= 'weekday'
            , height= 10
                 )
# fig.show()

# %%
# px.box(data_frame=df
#        ,x= 'sale_amount'
#        ,y= 'item_price'
#       )

# %%
# px.box(data_frame=df
#        ,y= 'sale_amount'
#        ,x= 'item_price'
#       )

# %%
# px.scatter(data_frame=df
#            ,x= 'sale_amount'
#            ,y= 'item_price'
#           )

# %%
# fig = px.scatter(data_frame=df
#            ,y= 'sale_amount'
#            ,x= 'item_price'
#            ,marginal_y= 'box'
#            ,marginal_x= 'box'
#            ,labels={'sale_amount': 'Sale Amount'
#                     ,'item_price': 'Price of Item'}
#           )
# fig.update_layout(title= 'Sale Amount per Item Price')

# %%
sale_agg = df.groupby('item_price', as_index=False).agg({'sale_amount':['min','mean','max']})

# %%
flat(sale_agg)
# Out:
#     item_price_  sale_amount_min  sale_amount_mean  sale_amount_max
# 0          0.60              3.0         29.249398             74.0
# 1          0.68              5.0         43.981763            119.0
# 2          0.74              5.0         40.355531             99.0
# 3          0.84              1.0         21.981599             59.0
# 4          0.98              8.0         47.644085            119.0
# 5          1.16              4.0         32.994852             83.0
# 6          1.68             15.0         76.950055            181.0
# 7          1.78              3.0         29.297864             81.0
# 8          1.79              6.0         51.389869            134.0
# 9          2.43              7.0         58.664321            193.0
# 10         2.61              1.0         18.358708             50.0
# 11         2.97              5.0         36.688116             96.0
# 12         3.14              0.0         22.010241             66.0
# ...

# %%
# fig = px.box(data_frame=sale_agg
#            ,y= ['sale_amount_max','sale_amount_mean','sale_amount_min']
#            ,x= 'item_price_'
#            ,facet_col= ['sale_amount_max','sale_amount_mean','sale_amount_min']
#            # ,marginal_y= 'box'
#            # ,marginal_x= 'box'
#            ,labels={'sale_amount': 'Sale Amount'
#                     ,'item_price': 'Price of Item'}
#           )
# fig.update_layout(title= 'Sale Amount per Item Price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 fig = px.box(data_frame=sale_agg
#       2            ,y= ['sale_amount_max','sale_amount_mean','sale_amount_min']
#       3            ,x= 'item_price_'
#       4            ,facet_col= ['sale_amount_max','sale_amount_mean','sale_amount_min']
#       5            # ,marginal_y= 'box'
#       6            # ,marginal_x= 'box'
#       7            ,labels={'sale_amount': 'Sale Amount'
#       8                     ,'item_price': 'Price of Item'}
#       9           )
#      10 fig.update_layout(title= 'Sale Amount per Item Price')
#
# ...

# %% [markdown]
# <a id="Store3"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 3. Set the index to be the datetime variable.

# %%
df_orig = df

# %%
df = df.set_index(df.sale_date)

# %% [markdown]
# <a id="Store4"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 4. Add a 'month' and 'day of week' column to your dataframe.

# %%
df['month']= df.index.month

# %%
df.weekday
# Out:
# sale_date
# 2013-01-01    Tue
# 2013-01-02    Wed
# 2013-01-03    Thu
# 2013-01-04    Fri
# 2013-01-05    Sat
#              ...
# 2017-12-27    Wed
# 2017-12-28    Thu
# 2017-12-29    Fri
# 2017-12-30    Sat
# 2017-12-31    Sun
# Name: weekday, Length: 913000, dtype: object

# %% [markdown]
# <a id="Store5"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df['sales_total'] = df.sale_amount * df.item_price

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 913000 entries, 2013-01-01 to 2017-12-31
# Data columns (total 17 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item           913000 non-null  int64
#  1   sale_amount    913000 non-null  float64
#  2   sale_date      913000 non-null  datetime64[ns]
#  3   sale_id        913000 non-null  int64
#  4   store          913000 non-null  int64
#  5   store_address  913000 non-null  object
#  6   store_city     913000 non-null  object
#  7   store_state    913000 non-null  object
#  8   store_zipcode  913000 non-null  object
#  9   item_brand     913000 non-null  object
#  10  item_name      913000 non-null  object
#  11  item_price     913000 non-null  float64
#  12  item_upc12     913000 non-null  object
#  13  item_upc14     913000 non-null  object
#  14  weekday        913000 non-null  object
#  15  month          913000 non-null  int64
# ...

# %% [markdown]
# <a id="Store6"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# #
# ## 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# <a id="OPS_0"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ## Using the OPS data:
# - acquired in the Acquire exercises `opsd_germany_daily.csv`, complete the following:

# %%
df = open_power_systems_data()

# %%
df
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# <a id="OPS_1"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 1. Convert date column to datetime format.

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#             date  consumption     wind   solar  wind+solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
df.date[0]
# Out:
# '2006-01-01'

# %%
df.date = pd.to_datetime(df.date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         4383 non-null   datetime64[ns]
#  1   consumption  4383 non-null   float64
#  2   wind         2920 non-null   float64
#  3   solar        2188 non-null   float64
#  4   wind+solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %% [markdown]
# <a id="OPS_2"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 2. Plot the distribution of each of your variables.

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
for i in df:
    df[i].plot()
    plt.title(i)
    plt.show()

# %% [markdown]
# <a id="OPS_3"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 3. Set the index to be the datetime variable.

# %%
df = df.set_index('date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   consumption  4383 non-null   float64
#  1   wind         2920 non-null   float64
#  2   solar        2188 non-null   float64
#  3   wind+solar   2187 non-null   float64
# dtypes: float64(4)
# memory usage: 171.2 KB

# %% [markdown]
# <a id="OPS_4"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 4. Add a month and a year column to your dataframe.

# %%
df.index.month_name()
# Out:
# Index(['January', 'January', 'January', 'January', 'January', 'January',
#        'January', 'January', 'January', 'January',
#        ...
#        'December', 'December', 'December', 'December', 'December', 'December',
#        'December', 'December', 'December', 'December'],
#       dtype='object', name='date', length=4383)

# %%
df['month'] = df.index.month_name()

# %%
df.index.year
# Out:
# Int64Index([2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006,
#             ...
#             2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017],
#            dtype='int64', name='date', length=4383)

# %%
df['year'] = df.index.year

# %% [markdown]
# <a id="OPS_5"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 5. Fill any missing values.

# %%
df.isnull()
# Out:
#             consumption   wind  solar  wind+solar  month   year
# date
# 2006-01-01        False   True   True        True  False  False
# 2006-01-02        False   True   True        True  False  False
# 2006-01-03        False   True   True        True  False  False
# 2006-01-04        False   True   True        True  False  False
# 2006-01-05        False   True   True        True  False  False
# ...                 ...    ...    ...         ...    ...    ...
# 2017-12-27        False  False  False       False  False  False
# 2017-12-28        False  False  False       False  False  False
# 2017-12-29        False  False  False       False  False  False
# 2017-12-30        False  False  False       False  False  False
# 2017-12-31        False  False  False       False  False  False
#
# [4383 rows x 6 columns]

# %%
df.asfreq('D', fill_value=0)
# Out:
#             consumption     wind   solar  wind+solar     month  year
# date
# 2006-01-01   1069.18400      NaN     NaN         NaN   January  2006
# 2006-01-02   1380.52100      NaN     NaN         NaN   January  2006
# 2006-01-03   1442.53300      NaN     NaN         NaN   January  2006
# 2006-01-04   1457.21700      NaN     NaN         NaN   January  2006
# 2006-01-05   1477.13100      NaN     NaN         NaN   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %%
df.fillna(0)
# Out:
#             consumption     wind   solar  wind+solar     month  year
# date
# 2006-01-01   1069.18400    0.000   0.000       0.000   January  2006
# 2006-01-02   1380.52100    0.000   0.000       0.000   January  2006
# 2006-01-03   1442.53300    0.000   0.000       0.000   January  2006
# 2006-01-04   1457.21700    0.000   0.000       0.000   January  2006
# 2006-01-05   1477.13100    0.000   0.000       0.000   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %%
df = df.fillna(0)

# %%
df
# Out:
#             consumption     wind   solar  wind+solar     month  year
# date
# 2006-01-01   1069.18400    0.000   0.000       0.000   January  2006
# 2006-01-02   1380.52100    0.000   0.000       0.000   January  2006
# 2006-01-03   1442.53300    0.000   0.000       0.000   January  2006
# 2006-01-04   1457.21700    0.000   0.000       0.000   January  2006
# 2006-01-05   1477.13100    0.000   0.000       0.000   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %% [markdown]
# <a id="OPS_6"> </a>
# <div class= "alert alert-block alert-info">
# </div>
#
# ***
#
# ### 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
from prepare import prepare_opsd

# %%
df = prepare_opsd()
df
# Out:
#             consumption     wind   solar  wind+solar     month  year
# date
# 2006-01-01   1069.18400    0.000   0.000       0.000   January  2006
# 2006-01-02   1380.52100    0.000   0.000       0.000   January  2006
# 2006-01-03   1442.53300    0.000   0.000       0.000   January  2006
# 2006-01-04   1457.21700    0.000   0.000       0.000   January  2006
# 2006-01-05   1477.13100    0.000   0.000       0.000   January  2006
# ...                 ...      ...     ...         ...       ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586  December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131  December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714  December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156  December  2017
#
# [4383 rows x 6 columns]

# %% [markdown]
# # FINAL CELL
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
